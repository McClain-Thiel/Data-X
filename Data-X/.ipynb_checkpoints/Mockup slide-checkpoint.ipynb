# %%
import pandas as pd

# %%
df = pd.DataFrame({'Team': ['Lakers', 'Hornets', 'Celtics', 'Bulls', 'Trailblazers'],
                  'Opponent' : ['Kings', 'Hawks', 'Rockets', 'Timberwolves', 'Bucks'], 
                  'Predicted winner': ['Lakers', 'Hornents', 'Rockets','Timberwolves', 'Bucks'],
                  'Predicted point spread' : ['+4', '+2.5', '+8', '+5' , '+2'],
                  'Predicted Total Score': [225, 208, 198, 247, 218],
                  'Vegas Winner': ['Lakers', 'Hawks', 'Rockets', 'Timberwolves', 'Trailblazers'],
                  'Vegas point spread': ['+5', '+2', '+6', '+4', '+3'],
                  'Vegas total score': [221,238, 211,209, 220]})
df
# Out:
#            Team      Opponent Predicted winner Predicted point spread  \
# 0        Lakers         Kings           Lakers                     +4
# 1       Hornets         Hawks         Hornents                   +2.5
# 2       Celtics       Rockets          Rockets                     +8
# 3         Bulls  Timberwolves     Timberwolves                     +5
# 4  Trailblazers         Bucks            Bucks                     +2
#
#    Predicted Total Score  Vegas Winner Vegas point spread  Vegas total score
# 0                    225        Lakers                 +5                221
# 1                    208         Hawks                 +2                238
# 2                    198       Rockets                 +6                211
# 3                    247  Timberwolves                 +4                209
# 4                    218  Trailblazers                 +3                220

# %%
def get_predictions(date):
    return df

# %%
#example of app usage
get_predictions('03/24/19')
# Out:
#            Team      Opponent Predicted winner Predicted point spread  \
# 0        Lakers         Kings           Lakers                     +4
# 1       Hornets         Hawks         Hornents                   +2.5
# 2       Celtics       Rockets          Rockets                     +8
# 3         Bulls  Timberwolves     Timberwolves                     +5
# 4  Trailblazers         Bucks            Bucks                     +2
#
#    Predicted Total Score  Vegas Winner Vegas point spread  Vegas total score
# 0                    225        Lakers                 +5                221
# 1                    208         Hawks                 +2                238
# 2                    198       Rockets                 +6                211
# 3                    247  Timberwolves                 +4                209
# 4                    218  Trailblazers                 +3                220
